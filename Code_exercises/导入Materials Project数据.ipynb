# %%
from matminer.data_retrieval.retrieve_MP import MPDataRetrieval

mpd=MPDataRetrieval(api_key='UAr4iZvEl7Kf1OId')
data=mpd.get_data('Fe2O3',['formula','band_gap'])#提取什么写什么
print(data)
# Out:
# [{'formula': {'Fe': 2.0, 'O': 3.0}, 'band_gap': 0.2603, 'material_id': 'mp-1244911'}, {'formula': {'Fe': 2.0, 'O': 3.0}, 'band_gap': 1.5673, 'material_id': 'mp-1456'}, {'formula': {'Fe': 2.0, 'O': 3.0}, 'band_gap': 1.0791, 'material_id': 'mp-1245078'}, {'formula': {'Fe': 2.0, 'O': 3.0}, 'band_gap': 1.0606, 'material_id': 'mp-1205415'}, {'formula': {'Fe': 2.0, 'O': 3.0}, 'band_gap': 0.0, 'material_id': 'mp-1068212'}, {'formula': {'Fe': 2.0, 'O': 3.0}, 'band_gap': 1.8628000000000005, 'material_id': 'mp-715572'}, {'formula': {'Fe': 2.0, 'O': 3.0}, 'band_gap': 0.14279999999999982, 'material_id': 'mp-776606'}, {'formula': {'Fe': 2.0, 'O': 3.0}, 'band_gap': 0.12109999999999999, 'material_id': 'mp-1245084'}, {'formula': {'Fe': 2.0, 'O': 3.0}, 'band_gap': 1.4464000000000001, 'material_id': 'mp-510080'}, {'formula': {'Fe': 2.0, 'O': 3.0}, 'band_gap': 0.0, 'material_id': 'mp-19770'}, {'formula': {'Fe': 2.0, 'O': 3.0}, 'band_gap': 0.0, 'material_id': 'mp-557546'}, {'formula': {'Fe': 2.0, 'O': 3
# ...

# %%
import pandas as pd

df=pd.DataFrame(data)
df
# Out:
#                   formula  band_gap material_id
# 0   {'Fe': 2.0, 'O': 3.0}    0.2603  mp-1244911
# 1   {'Fe': 2.0, 'O': 3.0}    1.5673     mp-1456
# 2   {'Fe': 2.0, 'O': 3.0}    1.0791  mp-1245078
# 3   {'Fe': 2.0, 'O': 3.0}    1.0606  mp-1205415
# 4   {'Fe': 2.0, 'O': 3.0}    0.0000  mp-1068212
# 5   {'Fe': 2.0, 'O': 3.0}    1.8628   mp-715572
# 6   {'Fe': 2.0, 'O': 3.0}    0.1428   mp-776606
# 7   {'Fe': 2.0, 'O': 3.0}    0.1211  mp-1245084
# 8   {'Fe': 2.0, 'O': 3.0}    1.4464   mp-510080
# 9   {'Fe': 2.0, 'O': 3.0}    0.0000    mp-19770
# 10  {'Fe': 2.0, 'O': 3.0}    0.0000   mp-557546
# 11  {'Fe': 2.0, 'O': 3.0}    1.4248   mp-715276
# 12  {'Fe': 2.0, 'O': 3.0}    0.0000   mp-716814
# 13  {'Fe': 2.0, 'O': 3.0}    1.4382   mp-542896
# 14  {'Fe': 2.0, 'O': 3.0}    0.0000  mp-1078361
# 15  {'Fe': 2.0, 'O': 3.0}    1.5764  mp-1178392
# 16  {'Fe': 2.0, 'O': 3.0}    0.9977   mp-685153
# 17  {'Fe': 2.0, 'O': 3.0}    0.1352  mp-1245277
# 18  {'Fe': 2.0, 'O': 3.0}    1.1157  mp-1245019
# ...
